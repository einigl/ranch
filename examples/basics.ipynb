# %% [markdown]
# # Basics of RANCH

# %%
import os
import sys

sys.path.insert(0, "..")

# %% [markdown]
# ## Structures

# %%
from ranch import Cube, Map, Profile

# %% [markdown]
# ## Simple example

# %%
path = os.path.join("..", "data")
filename = "13co10.fits"

cube = Cube.from_fits(filename, path=path)
print(cube)
# Out:
# Cube (nx: 325, ny: 434, nz: 80)

# %%
integ = cube.integral()
print(integ)

integ.show()
# Out:
# Map (nx: 325, ny: 434)

# %%
spect = cube.spectrum()
print(spect)

spect.show()
# Out:
# Profile (nz: 80)

# %%
integ.save_fits("integral", path="basics", overwrite=True)
spect.save_fits("spectrum", path="basics", overwrite=True)
